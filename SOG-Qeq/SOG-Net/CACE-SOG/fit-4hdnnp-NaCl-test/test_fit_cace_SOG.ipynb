# %% [markdown]
# ## 测试 `mace_qqz` 虚拟环境能否运行 `fit-cace-SOG.py`
#
# 1. 打开本 notebook 时，请在右上角选择 **`mace_qqz` 对应的 Python kernel**。
# 2. 先运行下面第一个代码单元，查看 Python、PyTorch 以及 CUDA 是否正常。
# 3. 再运行第二个代码单元，尝试执行 `fit-cace-SOG.py`（如只想测试导入是否成功，可先改成 `python fit-cace-SOG.py --help` 或在脚本中设置很小的训练步数）。

# %%
import sys, platform
print('Python version:', sys.version)
try:
    import torch
    print('PyTorch version:', torch.__version__)
    print('CUDA available:', torch.cuda.is_available())
    if torch.cuda.is_available():
        print('CUDA device count:', torch.cuda.device_count())
        print('Current device:', torch.cuda.current_device())
        print('Device name:', torch.cuda.get_device_name())
except ImportError as e:
    print('ImportError:', e)
# Out:
# Python version: 3.10.13 (main, Sep 11 2023, 13:44:35) [GCC 11.2.0]
# PyTorch version: 2.1.0+cu121
# CUDA available: False

# %%
# 在当前目录下测试运行 fit-cace-SOG.py
# 如只想快速测试环境，可先在脚本里设置很少的训练 epoch，或者改成加 --help

# !cd /dssg/home/acct-matxzl/matxzl/QiuQizhi/SOG-Qeq/SOG-Net/CACE-SOG/fit-4hdnnp-NaCl
# !pwd
# !python fit-cace-SOG.py
# Out:
# /dssg/home/acct-matxzl/matxzl/QiuQizhi/SOG-Qeq/SOG-Net/CACE-SOG/fit-4hdnnp-NaCl
# Traceback (most recent call last):
#   File "/dssg/home/acct-matxzl/matxzl/QiuQizhi/SOG-Qeq/SOG-Net/CACE-SOG/fit-4hdnnp-NaCl/fit-cace-SOG.py", line 15, in <module>
#     import cace
# ModuleNotFoundError: No module named 'cace'
