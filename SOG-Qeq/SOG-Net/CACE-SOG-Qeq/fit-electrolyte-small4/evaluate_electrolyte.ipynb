# %% [markdown]
# ## fit-electrolyte 评估：能量/力 MAE&RMSE + 电荷散点图（按元素）
#
# - **能量单位**：与 `electrolyte.xyz` header 中 `energy=` 一致（通常是 eV）
# - **力单位**：与 `Properties=...:forces` 一致（通常是 eV/Å）
# - **参考电荷**：extxyz `Properties` 里的 `q`（在 loader 中映射为 `charge`）

# %%
import os, sys
import torch

# Ensure working directory is this notebook's folder
try:
    THIS_DIR = os.path.abspath(os.path.dirname(__file__))
except NameError:
    THIS_DIR = os.getcwd()

os.chdir(THIS_DIR)

ROOT_DIR = os.path.abspath(os.path.join(THIS_DIR, ".."))
if ROOT_DIR not in sys.path:
    sys.path.insert(0, ROOT_DIR)

# %%
import os, sys
from pathlib import Path

import numpy as np
import torch
import matplotlib.pyplot as plt

import cace
from cace.representations import Cace
from cace.modules import BesselRBF, PolynomialCutoff
from cace.tools.scatter import scatter_sum
from cace.tools import torch_geometric
from cace.models.atomistic import NeuralNetworkPotential
from cace.data.extxyz_charge import read_extxyz_with_charge
from cace.tasks.load_data import random_train_valid_split
from cace.tools import Metrics

torch.set_default_dtype(torch.float32)

HERE = Path(os.getcwd()).resolve()
DATA_DIR = HERE
ROOT_DIR = DATA_DIR.parent
if str(ROOT_DIR) not in sys.path:
    sys.path.insert(0, str(ROOT_DIR))

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("DATA_DIR:", DATA_DIR)
print("device:", device)

# 数据路径（与 fit-cace-SOG.py 保持一致）
train_path = Path("/work/home/acrb3qk4vo/SOG-Qeq/SOG-Net/CACE-SOG-Qeq/fit-electrolyte-small3/electrolyte_200.xyz")
assert train_path.exists(), f"not found: {train_path}"

# 元素映射（与 fit-cace-SOG.py 保持一致）
z_map = {"H": 1, "O": 8, "F": 9, "K": 19}
Zs = [1, 8, 9, 19]
elements = [1, 8, 9, 19]

cutoff = 4.5
Fourier_node = 18  # SOG 核的分量数（ChargeEq 内部 SOG 参数个数）
# Out:
# DATA_DIR: /work/home/acrb3qk4vo/SOG-Qeq/SOG-Net/CACE-SOG-Qeq/fit-electrolyte-small3
# device: cpu

# %%
# 1) 读取数据 + 拆分 train/valid（与训练一致：valid_fraction=0.1, seed=1）
all_data = read_extxyz_with_charge(
    path=str(train_path),
    cutoff=cutoff,
    atomic_energies=None,
    z_map=z_map,
)
train_dataset, valid_dataset = random_train_valid_split(all_data, valid_fraction=0.1, seed=1)

train_loader = torch_geometric.DataLoader(train_dataset, batch_size=5, shuffle=True, drop_last=True)
valid_loader = torch_geometric.DataLoader(valid_dataset, batch_size=5, shuffle=False, drop_last=False)

print("train samples:", len(train_dataset))
print("valid samples:", len(valid_dataset))
# Out:
# train samples: 180
# valid samples: 20

# %%
# 2) 构建与训练同构的模型（含 Forces）
radial_basis = BesselRBF(cutoff=cutoff, n_rbf=6, trainable=True)
cutoff_fn = PolynomialCutoff(cutoff=cutoff)

rep = Cace(
    zs=Zs,
    n_atom_basis=2,
    embed_receiver_nodes=True,
    cutoff=cutoff,
    cutoff_fn=cutoff_fn,
    radial_basis=radial_basis,
    n_radial_basis=8,
    max_l=3,
    max_nu=3,
    num_message_passing=0,
    type_message_passing=["Bchi"],
    args_message_passing={"Bchi": {"shared_channels": False, "shared_l": False}},
    device=device,
    timeit=False,
    forward_features=["atomic_numbers"],
).to(device)

sr_energy = cace.modules.atomwise.Atomwise(
    n_layers=3,
    output_key="SR_energy",
    n_hidden=[32, 16],
    use_batchnorm=False,
    add_linear_nn=True,
)

chi = cace.modules.Atomwise(
    n_layers=3,
    n_hidden=[24, 12],
    n_out=1,
    per_atom_output_key="chi",
    output_key="tot_chi",
    residual=False,
    add_linear_nn=True,
    post_process=None,
    bias=False,
)

class SystemChargeFromAtomicCharges(torch.nn.Module):
    def __init__(self, charges_key: str = "charge", output_key: str = "system_charge"):
        super().__init__()
        self.charges_key = charges_key
        self.output_key = output_key
        self.model_outputs = [output_key]

    def forward(self, data: dict, **kwargs):
        if self.charges_key not in data or data[self.charges_key] is None:
            if data.get("batch", None) is None:
                num_graphs = 1
            else:
                num_graphs = int(data["batch"].max().item()) + 1 if data["batch"].numel() > 0 else 1
            data[self.output_key] = torch.zeros((num_graphs,), device=data["positions"].device, dtype=data["positions"].dtype)
            return data
        q = data[self.charges_key]
        if q.dim() > 1:
            q = q.view(-1)
        if data.get("batch", None) is None:
            system_q = q.sum().view(1)
        else:
            system_q = scatter_sum(q, data["batch"], dim=0)
        data[self.output_key] = system_q
        return data

system_charge_from_q = SystemChargeFromAtomicCharges("charge", "system_charge")

charge_eq = cace.modules.ChargeEq(
    dl=1.5,
    sigma=1.0,
    elements=elements,
    feature_key="chi",
    output_key="q_eq",
    ewald_key="SOG_potential",
    system_charge=None,
    remove_self_interaction=True,
    aggregation_mode="sum",
    use_sog_kernel=True,
    sog_num_components=Fourier_node,
)

e_add = cace.modules.FeatureAdd(
    feature_keys=["SR_energy", "SOG_potential"],
    output_key="CACE_energy",
)

forces = cace.modules.Forces(
    energy_key="CACE_energy",
    forces_key="CACE_forces",
    calc_stress=False,
)

model = NeuralNetworkPotential(
    input_modules=None,
    representation=rep,
    output_modules=[sr_energy, chi, system_charge_from_q, charge_eq, e_add, forces],
).to(device)

model.eval()
print(model)
# Out:
# NeuralNetworkPotential(
#   (postprocessors): ModuleList()
#   (representation): Cace(
#     (node_onehot): NodeEncoder(num_classes=4)
#     (node_embedding_sender): NodeEmbedding(num_classes=4, embedding_dim=2)
#     (node_embedding_receiver): NodeEmbedding(num_classes=4, embedding_dim=2)
#     (edge_coding): EdgeEncoder(directed=True)
#     (radial_basis): BesselRBF(cutoff=4.5, n_rbf=6, trainable=True)
#     (cutoff_fn): PolynomialCutoff(p=6.0, cutoff=4.5)
#     (angular_basis): AngularComponent(l_max=3)
#     (radial_transform): SharedRadialLinearTransform(
#       (weights): ParameterList(
#           (0): Parameter containing: [torch.float32 of size 6x8x4]
#           (1): Parameter containing: [torch.float32 of size 6x8x4]
#           (2): Parameter containing: [torch.float32 of size 6x8x4]
#           (3): Parameter containing: [torch.float32 of size 6x8x4]
#       )
#     )
#     (symmetrizer): Symmetrizer()
#     (message_passing_list): ModuleList()
#   )
#   (input_modules): ModuleList(
#     (0): Preprocess()
#   )
#   (output_modules): ModuleList(
#     (0-1): 2 x Atomwise()
#     (2): SystemChargeFromAtomicCharges()
#     (3): ChargeEq(
#       (ep): EwaldPotential()
#     )
#     (4): FeatureAdd()
#     (5): Forces (calc_forces=True, calc_stress=False,)
#   )
# )

# %%
# 3) 选择要评估的 checkpoint（对齐 fit-cace-Qeq-SOG.py）

ckpts = sorted(list((DATA_DIR).glob("*_model.pth")))
ckpts += sorted(list((DATA_DIR / "loss_data").glob("*_model.pth")))
ckpts += sorted(list(DATA_DIR.glob("hydrocarbon-model*.pth")))
ckpts += sorted(list(DATA_DIR.glob("best_model.pth")))

model_path = ckpts[0] if len(ckpts) > 0 else None
print("Found checkpoints:", len(ckpts))
if model_path is None:
    print("未找到可评估的模型文件（*.pth）。请先运行训练脚本生成模型，然后再运行后续 cells。")
else:
    print("Using checkpoint:", model_path)

    obj = torch.load(str(model_path), map_location=device, weights_only=False)
    if isinstance(obj, dict) and "model_state_dict" in obj:
        state_dict = obj["model_state_dict"]
        print("Loaded checkpoint dict (model_state_dict).")
    else:
        state_dict = obj.state_dict()
        print("Loaded full model object; using its state_dict.")

    # --- 从 checkpoint 权重形状推断表示层超参数 ---
    emb_w = state_dict.get("representation.node_embedding_sender.embedding_weights", None)
    rt_w0 = state_dict.get("representation.radial_transform.weights.0", None)
    if emb_w is None or rt_w0 is None:
        raise KeyError("checkpoint 缺少 representation 关键权重，无法自动推断网络结构")

    inferred_embed_dim = int(emb_w.shape[1])
    inferred_n_atom_basis = inferred_embed_dim
    inferred_n_radial_basis = int(rt_w0.shape[1])
    inferred_num_mp = 1 if any(k.startswith("representation.message_passing_list.0") for k in state_dict.keys()) else 0

    print("Inferred representation config from checkpoint:")
    print("  n_atom_basis:", inferred_n_atom_basis)
    print("  embedding_dim:", inferred_embed_dim)
    print("  n_radial_basis:", inferred_n_radial_basis)
    print("  num_message_passing:", inferred_num_mp)

    radial_basis = BesselRBF(cutoff=cutoff, n_rbf=6, trainable=True)
    cutoff_fn = PolynomialCutoff(cutoff=cutoff)

    rep = Cace(
        zs=Zs,
        n_atom_basis=inferred_n_atom_basis,
        embed_receiver_nodes=True,
        cutoff=cutoff,
        cutoff_fn=cutoff_fn,
        radial_basis=radial_basis,
        n_radial_basis=inferred_n_radial_basis,
        max_l=3,
        max_nu=3,
        num_message_passing=inferred_num_mp,
        type_message_passing=["Bchi"],
        args_message_passing={"Bchi": {"shared_channels": False, "shared_l": False}},
        device=device,
        timeit=False,
        forward_features=["atomic_numbers"],
    ).to(device)

    sr_energy = cace.modules.atomwise.Atomwise(
        n_layers=3,
        output_key="SR_energy",
        n_hidden=[32, 16],
        use_batchnorm=False,
        add_linear_nn=True,
    )

    chi = cace.modules.Atomwise(
        n_layers=3,
        n_hidden=[24, 12],
        n_out=1,
        per_atom_output_key="chi",
        output_key="tot_chi",
        residual=False,
        add_linear_nn=True,
        post_process=torch.square,
        bias=False,
    )

    # 与训练脚本一致：加入 chi_bias
    chi_bias = cace.modules.ElementwiseFeatureBias(
        elements=[1, 8, 9, 19],
        feature_key="chi",
        output_key="chi_biased",
        init_bias={1: -0.5, 8: 0.5, 9: -0.5, 19: 0.5},
        use_scale=True,
        init_scale=5.0,
        zero_mean_bias=True,
    )

    class SystemChargeFromAtomicCharges(torch.nn.Module):
        def __init__(self, charges_key: str = "charge", output_key: str = "system_charge"):
            super().__init__()
            self.charges_key = charges_key
            self.output_key = output_key
            self.model_outputs = [output_key]

        def forward(self, data: dict, **kwargs):
            if self.charges_key not in data or data[self.charges_key] is None:
                if data.get("batch", None) is None:
                    num_graphs = 1
                else:
                    num_graphs = int(data["batch"].max().item()) + 1 if data["batch"].numel() > 0 else 1
                data[self.output_key] = torch.zeros((num_graphs,), device=data["positions"].device, dtype=data["positions"].dtype)
                return data

            q = data[self.charges_key]
            if q.dim() > 1:
                q = q.view(-1)
            if data.get("batch", None) is None:
                system_q = q.sum().view(1)
            else:
                system_q = scatter_sum(q, data["batch"], dim=0)
            data[self.output_key] = system_q
            return data

    system_charge_from_q = SystemChargeFromAtomicCharges("charge", "system_charge")

    # 与训练脚本一致：ChargeEq 读 chi_biased
    charge_eq = cace.modules.ChargeEq(
        dl=1.5,
        sigma=1.0,
        elements=elements,
        feature_key="chi_biased",
        output_key="q_eq",
        ewald_key="SOG_potential",
        system_charge=None,
        remove_self_interaction=True,
        aggregation_mode="sum",
        use_sog_kernel=True,
        sog_num_components=Fourier_node,
    )

    e_add = cace.modules.FeatureAdd(
        feature_keys=["SR_energy", "SOG_potential"],
        output_key="CACE_energy",
    )

    forces = cace.modules.Forces(
        energy_key="CACE_energy",
        forces_key="CACE_forces",
        calc_stress=False,
    )

    model = NeuralNetworkPotential(
        input_modules=None,
        representation=rep,
        # 与训练脚本顺序一致
        output_modules=[sr_energy, chi, chi_bias, system_charge_from_q, charge_eq, e_add, forces],
    ).to(device)

    # --- 兼容旧评估模型索引偏差：将 output_modules.4.(ChargeEq) 映射到 output_modules.3 ---
    print("REMAPPING ENABLED: output_modules.4.(ChargeEq) -> output_modules.3 when needed")
    remapped_state = dict(state_dict)
    for k in ["J_raw", "sog_log_alpha", "sog_weights", "Z_index_map"]:
        k_train = f"output_modules.4.{k}"
        k_eval = f"output_modules.3.{k}"
        if k_train in remapped_state and k_eval not in remapped_state:
            remapped_state[k_eval] = remapped_state[k_train]
            print("mapped:", k_train, "->", k_eval)

    missing, unexpected = model.load_state_dict(remapped_state, strict=False)
    print("missing keys:", missing)
    print("unexpected keys:", unexpected)

    model.to(device)
    model.eval()
# Out:
# Found checkpoints: 7
# Using checkpoint: /work/home/acrb3qk4vo/SOG-Qeq/SOG-Net/CACE-SOG-Qeq/fit-electrolyte-small3/best_model.pth
# Loaded full model object; using its state_dict.
# Inferred representation config from checkpoint:
#   n_atom_basis: 4
#   embedding_dim: 4
#   n_radial_basis: 12
#   num_message_passing: 1
# REMAPPING ENABLED: output_modules.4.(ChargeEq) -> output_modules.3 when needed
# mapped: output_modules.4.J_raw -> output_modules.3.J_raw
# mapped: output_modules.4.sog_log_alpha -> output_modules.3.sog_log_alpha
# mapped: output_modules.4.sog_weights -> output_modules.3.sog_weights
# mapped: output_modules.4.Z_index_map -> output_modules.3.Z_index_map
# missing keys: []
# unexpected keys: ['representation.message_passing_list.0.2.hnet.0.linear.weight', 'representation.message_passing_list.0.2.hnet.0.linear.bias', 'output_modules.0.outnet.0.linear.weight', 'output_modules.0.outnet.0.linear.bias', 'output_modules.0.outnet.1.linear.weight', 'output_modules.0.outnet.1.linear.bias', 'output_modules.0.outnet.2.linear.weight', 'output_modules.0.outnet.2.linear.bias', 'output_modules.0.linear_nn.linear.weight', 'output_modules.0.linear_nn.linear.bias', 'output_modules.1.outnet.0.linear.weight', 'output_modules.1.outnet.1.linear.weight', 'output_modules.1.outnet.2.linear.weight', 'output_modules.1.linear_nn.linear.weight', 'output_modules.3.J_raw', 'output_modules.3.sog_log_alpha', 'output_modules.3.sog_weights', 'output_modules.3.Z_index_map']

# %%
# 4) 计算 train/valid 的能量与力 MAE/RMSE（对齐训练时 Metrics 的定义）
# - energy: per_atom=True -> 单位约为 (energy单位)/atom
# - forces: component-wise -> 单位约为 (forces单位)

if "model_path" in globals() and model_path is None:
    print("跳过：未加载 checkpoint。先运行上一格并确保找到 .pth 文件。")
else:
    e_metric_train = Metrics(target_name="energy", predict_name="CACE_energy", name="e/atom", per_atom=True)
    e_metric_valid = Metrics(target_name="energy", predict_name="CACE_energy", name="e/atom", per_atom=True)
    f_metric_train = Metrics(target_name="forces", predict_name="CACE_forces", name="f")
    f_metric_valid = Metrics(target_name="forces", predict_name="CACE_forces", name="f")

    for batch in train_loader:
        batch = batch.to(device)
        d = batch.to_dict()
        d["positions"] = d["positions"].detach().requires_grad_(True)
        out = model(d, training=False)
        e_metric_train.update_metrics("train", out, d)
        f_metric_train.update_metrics("train", out, d)

    for batch in valid_loader:
        batch = batch.to(device)
        d = batch.to_dict()
        d["positions"] = d["positions"].detach().requires_grad_(True)
        out = model(d, training=False)
        e_metric_valid.update_metrics("val", out, d)
        f_metric_valid.update_metrics("val", out, d)

    train_e = e_metric_train.retrieve_metrics("train", clear=False, print_log=False)
    val_e   = e_metric_valid.retrieve_metrics("val", clear=False, print_log=False)
    train_f = f_metric_train.retrieve_metrics("train", clear=False, print_log=False)
    val_f   = f_metric_valid.retrieve_metrics("val", clear=False, print_log=False)

    print("=== Metrics ===")
    print("Train e/atom MAE, RMSE:", float(train_e["mae"]), float(train_e["rmse"]))
    print("Valid e/atom MAE, RMSE:", float(val_e["mae"]), float(val_e["rmse"]))
    print("Train f MAE, RMSE:", float(train_f["mae"]), float(train_f["rmse"]))
    print("Valid f MAE, RMSE:", float(val_f["mae"]), float(val_f["rmse"]))

    print("\n=== Units ===")
    print("energy: 与 electrolyte.xyz header 的 energy= 一致（通常 eV）；e/atom 为每原子能量误差（eV/atom）")
    print("forces: 与 electrolyte.xyz 的 forces 列一致（通常 eV/Å）")
    print("charge: 与 electrolyte.xyz 的 q 列一致（通常 e）")
# Out:
# === Metrics ===
# Train e/atom MAE, RMSE: 0.08777803182601929 0.11075400561094284
# Valid e/atom MAE, RMSE: 0.07983417809009552 0.09691092371940613
# Train f MAE, RMSE: 0.5869847536087036 0.7945060729980469
# Valid f MAE, RMSE: 0.5894076228141785 0.8010802865028381
#
# === Units ===
# energy: 与 electrolyte.xyz header 的 energy= 一致（通常 eV）；e/atom 为每原子能量误差（eV/atom）
# forces: 与 electrolyte.xyz 的 forces 列一致（通常 eV/Å）
# charge: 与 electrolyte.xyz 的 q 列一致（通常 e）

# %%
# 6) 按元素查看 chi 分布（valid）：chi_biased = s*chi + b_Z（与 Qeq 输入一致，见 Qeq_chi_bias_changes_summary.md）
if "model_path" in globals() and model_path is None:
    print("跳过：未加载 checkpoint。先运行上面的 checkpoint cell 并确保找到 .pth 文件。")
else:
    chi_b_list, chi_raw_list, z_list = [], [], []
    for batch in valid_loader:
        batch = batch.to(device)
        d = batch.to_dict()
        d["positions"] = d["positions"].detach().requires_grad_(True)
        out = model(d, training=False)
        if "chi_biased" not in out:
            raise KeyError(
                "forward 中缺少 'chi_biased'。若模型含 chi_bias 且 ChargeEq.feature_key='chi_biased'，"
                "请确认 checkpoint/模型定义一致；无 bias 的旧模型可改为 out['chi']。"
            )
        chi_b = out["chi_biased"].detach().view(-1).cpu().numpy()
        chi_raw = out["chi"].detach().view(-1).cpu().numpy()
        z = d["atomic_numbers"].detach().view(-1).cpu().numpy()
        chi_b_list.append(chi_b)
        chi_raw_list.append(chi_raw)
        z_list.append(z)
    chi_b_all = np.concatenate(chi_b_list)
    chi_raw_all = np.concatenate(chi_raw_list)
    z_all = np.concatenate(z_list)
    elem_names = {1: "H", 8: "O", 9: "F", 19: "K"}
    colors = {1: "#1f77b4", 8: "#d62728", 9: "#2ca02c", 19: "#ff7f0e"}
    print("chi_biased min/max:", float(chi_b_all.min()), float(chi_b_all.max()))
    print("chi_raw min/max:", float(chi_raw_all.min()), float(chi_raw_all.max()))
    print("\n=== chi_biased stats by element (valid) ===")
    for Z in sorted(set(z_all.tolist())):
        m = z_all == Z
        mu_b = float(chi_b_all[m].mean())
        std_b = float(chi_b_all[m].std())
        mu_raw = float(chi_raw_all[m].mean())
        std_raw = float(chi_raw_all[m].std())
        print(
            f"{elem_names.get(int(Z), str(int(Z)))}(Z={int(Z)}): "
            f"chi_biased mean/std=({mu_b:.6g},{std_b:.6g}) | chi_raw mean/std=({mu_raw:.6g},{std_raw:.6g})"
        )
    fig, ax = plt.subplots(1, 1, figsize=(7.2, 5.0))
    for Z in sorted(set(z_all.tolist())):
        m = z_all == Z
        ax.hist(
            chi_b_all[m],
            bins=80,
            density=True,
            alpha=0.45,
            label=f"{elem_names.get(int(Z), str(int(Z)))} (Z={int(Z)})",
            color=colors.get(int(Z), None),
        )
    ax.set_xlabel("chi_biased (per-atom, ChargeEq input)")
    ax.set_ylabel("density")
    ax.set_title("chi_biased distribution by element (valid)")
    ax.grid(True, alpha=0.25)
    ax.legend(fontsize=9)
    plt.show()
    fig, ax = plt.subplots(1, 1, figsize=(7.2, 5.0))
    for Z in sorted(set(z_all.tolist())):
        m = z_all == Z
        ax.hist(
            chi_raw_all[m],
            bins=80,
            density=True,
            alpha=0.45,
            label=f"{elem_names.get(int(Z), str(int(Z)))} (Z={int(Z)})",
            color=colors.get(int(Z), None),
        )
    ax.set_xlabel("chi_raw")
    ax.set_ylabel("density")
    ax.set_title("chi_raw distribution by element (valid)")
    ax.grid(True, alpha=0.25)
    ax.legend(fontsize=9)
    plt.show()
# Out:
# chi_biased min/max: -1.2999151945114136 1.5022776126861572
# chi_raw min/max: -0.08330491930246353 0.18218225240707397
#
# === chi_biased stats by element (valid) ===
# H(Z=1): chi_biased mean/std=(-1.11889,0.0503646) | chi_raw mean/std=(-0.0343734,0.0136136)
# O(Z=8): chi_biased mean/std=(1.29643,0.0443394) | chi_raw mean/std=(0.041477,0.011985)
# F(Z=9): chi_biased mean/std=(1.31422,0.0675302) | chi_raw mean/std=(0.0521939,0.0182534)
# K(Z=19): chi_biased mean/std=(-0.908064,0.106704) | chi_raw mean/std=(0.0984776,0.0288421)

# %%
# 输出 chi 真实分布（valid）：优先使用 Qeq 输入 chi_biased，同时给出 chi_raw
import numpy as np
import matplotlib.pyplot as plt

if "model_path" in globals() and model_path is None:
    print("跳过：未加载 checkpoint。")
else:
    chi_b_list, chi_raw_list, z_list = [], [], []

    for batch in valid_loader:
        batch = batch.to(device)
        d = batch.to_dict()
        d["positions"] = d["positions"].detach().requires_grad_(True)
        out = model(d, training=False)

        # Qeq 实际输入（真实用于求解）
        if "chi_biased" in out:
            chi_b = out["chi_biased"].detach().view(-1).cpu().numpy()
        else:
            # 没有 bias 模块时退化为 chi
            chi_b = out["chi"].detach().view(-1).cpu().numpy()

        # 原始 chi（若有 chi_raw 就用；否则用 chi）
        if "chi_raw" in out:
            chi_raw = out["chi_raw"].detach().view(-1).cpu().numpy()
        else:
            chi_raw = out["chi"].detach().view(-1).cpu().numpy()

        z = d["atomic_numbers"].detach().view(-1).cpu().numpy()

        chi_b_list.append(chi_b)
        chi_raw_list.append(chi_raw)
        z_list.append(z)

    chi_b_all = np.concatenate(chi_b_list)
    chi_raw_all = np.concatenate(chi_raw_list)
    z_all = np.concatenate(z_list)

    elem_names = {1: "H", 8: "O", 9: "F", 19: "K"}
    colors = {1: "#1f77b4", 8: "#d62728", 9: "#2ca02c", 19: "#ff7f0e"}

    print("chi_biased min/max:", float(chi_b_all.min()), float(chi_b_all.max()))
    print("chi_raw   min/max:", float(chi_raw_all.min()), float(chi_raw_all.max()))
    print("\n=== chi stats by element (valid) ===")
    for Z in sorted(set(z_all.tolist())):
        m = (z_all == Z)
        print(
            f"{elem_names.get(int(Z), str(int(Z)))}(Z={int(Z)}): "
            f"chi_biased mean/std=({chi_b_all[m].mean():.6g},{chi_b_all[m].std():.6g}) | "
            f"chi_raw mean/std=({chi_raw_all[m].mean():.6g},{chi_raw_all[m].std():.6g})"
        )

    # 直方图1：chi_biased（Qeq真正使用）
    fig, ax = plt.subplots(figsize=(7.2, 5.0))
    for Z in sorted(set(z_all.tolist())):
        m = (z_all == Z)
        ax.hist(
            chi_b_all[m], bins=80, density=True, alpha=0.45,
            label=f"{elem_names.get(int(Z), str(int(Z)))} (Z={int(Z)})",
            color=colors.get(int(Z), None),
        )
    ax.set_xlabel("chi_biased (used by ChargeEq)")
    ax.set_ylabel("density")
    ax.set_title("chi_biased distribution by element (valid)")
    ax.grid(True, alpha=0.25)
    ax.legend(fontsize=9)
    plt.show()

    # 直方图2：chi_raw
    fig, ax = plt.subplots(figsize=(7.2, 5.0))
    for Z in sorted(set(z_all.tolist())):
        m = (z_all == Z)
        ax.hist(
            chi_raw_all[m], bins=80, density=True, alpha=0.45,
            label=f"{elem_names.get(int(Z), str(int(Z)))} (Z={int(Z)})",
            color=colors.get(int(Z), None),
        )
    ax.set_xlabel("chi_raw")
    ax.set_ylabel("density")
    ax.set_title("chi_raw distribution by element (valid)")
    ax.grid(True, alpha=0.25)
    ax.legend(fontsize=9)
    plt.show()
# Out:
# chi_biased min/max: -1.2999151945114136 1.5022776126861572
# chi_raw   min/max: -0.08330491930246353 0.18218225240707397
#
# === chi stats by element (valid) ===
# H(Z=1): chi_biased mean/std=(-1.11889,0.0503646) | chi_raw mean/std=(-0.0343734,0.0136136)
# O(Z=8): chi_biased mean/std=(1.29643,0.0443394) | chi_raw mean/std=(0.041477,0.011985)
# F(Z=9): chi_biased mean/std=(1.31422,0.0675302) | chi_raw mean/std=(0.0521939,0.0182534)
# K(Z=19): chi_biased mean/std=(-0.908064,0.106704) | chi_raw mean/std=(0.0984776,0.0288421)

# %%
# 7) 按元素查看硬度 J：优先使用 out['J_i'] / out['J_elem']（若存在）

if "model_path" in globals() and model_path is None:
    print("跳过：未加载 checkpoint。先运行上面的 checkpoint cell 并确保找到 .pth 文件。")
else:
    # 取一个 batch 探测 key
    _batch = next(iter(valid_loader)).to(device)
    _d = _batch.to_dict()
    _d["positions"] = _d["positions"].detach().requires_grad_(True)
    _out = model(_d, training=False)

    print("Available keys in model output:")
    print(sorted(list(_out.keys())))

    if ("J_i" not in _out) and ("J_elem" not in _out):
        print("\n当前输出里没有 J_i / J_elem。")
        print("如果你确定用的是修改后的 cace/modules/charge_eq.py（model_outputs 含 J_i/J_elem），")
        print("但这里仍看不到，通常是因为：checkpoint 来自旧代码版本，或 state_dict 没包含该模块参数。")
    else:
        # 收集 valid 全集的 J_i（每原子）
        J_list, z_list = [], []
        J_elem_last = None

        for batch in valid_loader:
            batch = batch.to(device)
            d = batch.to_dict()
            d["positions"] = d["positions"].detach().requires_grad_(True)
            out = model(d, training=False)

            if "J_i" in out:
                Ji = out["J_i"].detach().view(-1).cpu().numpy()
                J_list.append(Ji)
            if "J_elem" in out:
                J_elem_last = out["J_elem"].detach().view(-1).cpu().numpy()

            z = d["atomic_numbers"].detach().view(-1).cpu().numpy()
            z_list.append(z)

        z_all = np.concatenate(z_list)
        if len(J_list) > 0:
            J_all = np.concatenate(J_list)
            print("\nJ_i min/max:", float(J_all.min()), float(J_all.max()))

            elem_names = {1: "H", 8: "O", 9: "F", 19: "K"}
            colors = {1: "#1f77b4", 8: "#d62728", 9: "#2ca02c", 19: "#ff7f0e"}

            print("\n=== J_i stats by element (valid) ===")
            for Z in sorted(set(z_all.tolist())):
                m = z_all == Z
                mu = float(J_all[m].mean())
                std = float(J_all[m].std())
                print(f"{elem_names.get(int(Z), str(int(Z)))}(Z={int(Z)}): J_i mean/std=({mu:.6g},{std:.6g})")

            fig, ax = plt.subplots(1, 1, figsize=(7.2, 5.0))
            for Z in sorted(set(z_all.tolist())):
                m = z_all == Z
                ax.hist(
                    J_all[m],
                    bins=80,
                    density=True,
                    alpha=0.45,
                    label=f"{elem_names.get(int(Z), str(int(Z)))} (Z={int(Z)})",
                    color=colors.get(int(Z), None),
                )
            ax.set_xlabel("J_i (per-atom hardness)")
            ax.set_ylabel("density")
            ax.set_title("J_i distribution by element (valid)")
            ax.grid(True, alpha=0.25)
            ax.legend(fontsize=9)
            plt.show()

        if J_elem_last is not None:
            print("\nJ_elem (by elements order in ChargeEq.elements):")
            print("elements:", elements)
            print("J_elem:", J_elem_last)
# Out:
# Available keys in model output:
# ['CACE_energy', 'CACE_forces', 'J_elem', 'J_i', 'SOG_potential', 'SR_energy', 'chi', 'chi_biased', 'q_eq', 'system_charge', 'tot_chi']
#
# J_i min/max: 0.9783294796943665 7.045198440551758
#
# === J_i stats by element (valid) ===
# H(Z=1): J_i mean/std=(2.4895,0)
# O(Z=8): J_i mean/std=(0.97833,5.96046e-08)
# F(Z=9): J_i mean/std=(2.55044,4.76837e-07)
# K(Z=19): J_i mean/std=(7.0452,0)
# J_elem (by elements order in ChargeEq.elements):
# elements: [1, 8, 9, 19]
# J_elem: [2.4894974 0.9783295 2.5504365 7.0451984]

# %%
# 5) 计算电荷：按元素画 q_ref vs q_pred 散点图

if "model_path" in globals() and model_path is None:
    print("跳过：未加载 checkpoint。先运行上一格并确保找到 .pth 文件。")
else:
    q_pred_list, q_ref_list, z_list = [], [], []

    for batch in valid_loader:
        batch = batch.to(device)
        d = batch.to_dict()
        # 电荷不需要 Forces 的梯度，但模型里含 Forces，为避免 Forces 触发 autograd，
        # 这里仍然给 positions 设 requires_grad=True（开销可接受）。
        d["positions"] = d["positions"].detach().requires_grad_(True)
        out = model(d, training=False)

        q_pred = out["q_eq"].detach().view(-1).cpu().numpy()
        q_ref  = d["charge"].detach().view(-1).cpu().numpy()
        z      = d["atomic_numbers"].detach().view(-1).cpu().numpy()

        q_pred_list.append(q_pred)
        q_ref_list.append(q_ref)
        z_list.append(z)

    q_pred_all = np.concatenate(q_pred_list)
    q_ref_all  = np.concatenate(q_ref_list)
    z_all      = np.concatenate(z_list)

    print("Total atoms(valid):", len(q_pred_all))
    print("q_ref  min/max:", float(q_ref_all.min()), float(q_ref_all.max()))
    print("q_pred min/max:", float(q_pred_all.min()), float(q_pred_all.max()))

    elem_names = {1: "H", 8: "O", 9: "F", 19: "K"}
    colors = {1: "#1f77b4", 8: "#d62728", 9: "#2ca02c", 19: "#ff7f0e"}

    fig, ax = plt.subplots(1, 1, figsize=(6.5, 6))
    for Z in sorted(set(z_all.tolist())):
        mask = z_all == Z
        ax.scatter(
            q_ref_all[mask],
            q_pred_all[mask],
            s=6,
            alpha=0.35,
            label=f"{elem_names.get(int(Z), str(int(Z)))} (Z={int(Z)})",
            color=colors.get(int(Z), None),
        )

    mn = float(min(q_ref_all.min(), q_pred_all.min()))
    mx = float(max(q_ref_all.max(), q_pred_all.max()))
    ax.plot([mn, mx], [mn, mx], "k--", lw=1, label="y=x")
    ax.set_xlabel("q_ref (extxyz q)")
    ax.set_ylabel("q_pred (Qeq q_eq)")
    ax.set_title("Electrolyte: q_ref vs q_pred by element (valid)")
    ax.grid(True, alpha=0.25)
    ax.legend(markerscale=2, fontsize=9)
    ax.set_aspect("equal", adjustable="box")
    plt.show()
# Out:
# Total atoms(valid): 7950
# q_ref  min/max: -1.0 1.0
# q_pred min/max: -1.310284972190857 0.6087252497673035

# %%
# 8) 输出 SR/LR 贡献（SR_energy 与 SOG_potential）并做统计
if "model_path" in globals() and model_path is None:
    print("跳过：未加载 checkpoint。先运行上面的 checkpoint cell 并确保找到 .pth 文件。")
else:
    import numpy as np
    def collect_sr_lr(loader, subset_name):
        sr_all = []
        lr_all = []
        e_all = []
        for batch in loader:
            batch = batch.to(device)
            d = batch.to_dict()
            # 模型里如果包含 Forces，需让 positions 参与图构建
            d["positions"] = d["positions"].detach().requires_grad_(True)
            out = model(d, training=False)
            if "SR_energy" not in out or "SOG_potential" not in out:
                print(f"[{subset_name}] 缺少 SR_energy 或 SOG_potential，out.keys() = {list(out.keys())}")
                return
            sr = out["SR_energy"].detach().view(-1).cpu().numpy()
            lr = out["SOG_potential"].detach().view(-1).cpu().numpy()
            # 总能量键通常是 CACE_energy；若不存在可退化到 energy
            if "CACE_energy" in out:
                e = out["CACE_energy"].detach().view(-1).cpu().numpy()
            elif "energy" in out:
                e = out["energy"].detach().view(-1).cpu().numpy()
            else:
                e = np.zeros_like(sr)
            sr_all.append(sr)
            lr_all.append(lr)
            e_all.append(e)
        if len(sr_all) == 0:
            print(f"[{subset_name}] 没有收集到数据。")
            return
        sr_all = np.concatenate(sr_all)
        lr_all = np.concatenate(lr_all)
        e_all = np.concatenate(e_all)
        print(f"\n=== {subset_name} SR/LR stats ===")
        print("N structures:", len(sr_all))
        print("SR_energy mean/std:", float(sr_all.mean()), float(sr_all.std()))
        print("SOG_potential mean/std:", float(lr_all.mean()), float(lr_all.std()))
        print("CACE_energy mean/std:", float(e_all.mean()), float(e_all.std()))
        # 一致性检查：SR + LR 与总能量差值
        if len(e_all) == len(sr_all):
            diff = (sr_all + lr_all) - e_all
            print("|SR+LR-CACE| mean/std/max:",
                  float(np.mean(np.abs(diff))),
                  float(np.std(np.abs(diff))),
                  float(np.max(np.abs(diff))))
        # LR 相对 SR 的量级
        ratio = np.abs(lr_all) / np.clip(np.abs(sr_all), 1e-12, None)
        print("|LR|/|SR| mean/median/p95:",
              float(ratio.mean()),
              float(np.median(ratio)),
              float(np.percentile(ratio, 95)))
    collect_sr_lr(train_loader, "train")
    collect_sr_lr(valid_loader, "valid")
# Out:
# === train SR/LR stats ===
# N structures: 180
# SR_energy mean/std: -62.04310989379883 39.84865951538086
# SOG_potential mean/std: 4.299333572387695 2.319545030593872
# CACE_energy mean/std: -57.74378204345703 37.55843734741211
# |SR+LR-CACE| mean/std/max: 0.0 0.0 0.0
# |LR|/|SR| mean/median/p95: 0.07376471906900406 0.07455383241176605 0.0875944085419178
#
# === valid SR/LR stats ===
# N structures: 20
# SR_energy mean/std: -70.35636138916016 43.04192352294922
# SOG_potential mean/std: 4.798545837402344 2.5601439476013184
# CACE_energy mean/std: -65.55781555175781 40.497657775878906
# |SR+LR-CACE| mean/std/max: 0.0 0.0 0.0
# |LR|/|SR| mean/median/p95: 0.0721806064248085 0.06987179815769196 0.0878436341881752

# %%
# 打印最终 chi_bias 的 scale / bias（来自当前已加载模型）

import numpy as np

if "model" not in globals():
    print("未检测到 model。请先运行模型构建与 checkpoint 加载单元。")
else:
    # 在 output_modules 中查找 ElementwiseFeatureBias（包含 bias/scale 参数）
    chi_bias_mod = None
    for m in model.output_modules:
        if hasattr(m, "bias") and hasattr(m, "scale"):
            chi_bias_mod = m
            break

    if chi_bias_mod is None:
        print("未找到 chi_bias 模块（ElementwiseFeatureBias）。")
    else:
        scale = float(chi_bias_mod.scale.detach().cpu().item())
        bias = chi_bias_mod.bias.detach().cpu().numpy()

        # 若 zero_mean_bias=True，Qeq 实际使用的是去均值后的偏置
        if getattr(chi_bias_mod, "zero_mean_bias", False):
            bias_eff = bias - bias.mean()
        else:
            bias_eff = bias

        elements = getattr(chi_bias_mod, "elements", None)
        elem_names = {1: "H", 8: "O", 9: "F", 19: "K"}

        print("final scale:", scale)
        print("raw bias:", bias)
        print("effective bias used in forward:", bias_eff)

        if elements is not None and len(elements) == len(bias):
            print("\nper-element bias:")
            for z, b_raw, b_use in zip(elements, bias, bias_eff):
                name = elem_names.get(int(z), str(int(z)))
                print(f"{name}(Z={int(z)}): raw={float(b_raw):.6g}, used={float(b_use):.6g}")
# Out:
# final scale: 3.69958758354187
# raw bias: [1.541018  3.6757243 3.6538665 1.2603487]
# effective bias used in forward: [-0.9917214  1.1429849  1.1211271 -1.2723907]
#
# per-element bias:
# H(Z=1): raw=1.54102, used=-0.991721
# O(Z=8): raw=3.67572, used=1.14298
# F(Z=9): raw=3.65387, used=1.12113
# K(Z=19): raw=1.26035, used=-1.27239
