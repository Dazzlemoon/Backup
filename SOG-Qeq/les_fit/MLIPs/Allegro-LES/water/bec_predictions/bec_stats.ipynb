# %%
from ase.io import read
import numpy as np
import sys

ref_xyz = read('../../data-sets/h2o_bec.xyz', index=':')

nequip_xyz = read('lr_water_r45_nlayer3_lmax2.xyz', index=':')

epsilon_r = 1.78 # float(sys.argv[2])
# collect all the bec tensors

bec_refs = []
bec_preds = []

for xyz in ref_xyz:
    # get the bec tensor
    bec_ref = xyz.get_array('BEC')

    # append to the list
    bec_refs.append(bec_ref)

for xyz in nequip_xyz:
    bec_pred = xyz.get_array('LES_BEC') * epsilon_r**0.5 *-1
    bec_preds.append(bec_pred)

# convert to numpy arrays
bec_refs = np.array(bec_refs)
bec_preds = np.array(bec_preds)

# calculate the errors
bec_errors = bec_refs - bec_preds
# calculate the mean and std
mae = np.mean(np.abs(bec_errors))
rmse = np.sqrt(np.mean(bec_errors**2))
r2 = 1 - np.sum(bec_errors**2) / np.sum((bec_refs - np.mean(bec_refs))**2)
# print the results
print('MAE: ', mae)
print('RMSE: ', rmse)
print('R2: ', r2)
# Out:
# MAE:  0.03895196173862021
# RMSE:  0.05573809052211445
# R2:  0.9803843606776675

# %%
# print(bec_refs[0][0])
# print(bec_preds[0][0])
