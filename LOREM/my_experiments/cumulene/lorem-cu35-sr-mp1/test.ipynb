# %%
# !cd /data/home/public/qiuqizhi/LOREM/my_experiments/cumulene/lorem-cu35-sr-mp1

# %%
# !ls
# Out:
# err_38.out  log_38.out	model.yaml  run  run.slurm  settings.yaml  test.ipynb

# %%
# !python /data/home/public/qiuqizhi/LOREM/lorem/metrics_cumulene.py
# Out:
# /data/home/public/qiuqizhi/LOREM/marathon/marathon/extra/hermes/data_source/flatten_atoms.py:89: FutureWarning: Please use atoms.calc = calc
#   atoms.set_calculator(calc)
# /data/home/public/qiuqizhi/LOREM/marathon/marathon/extra/hermes/data_source/flatten_atoms.py:74: FutureWarning: Please use atoms.calc = calc
#   atoms.set_calculator(calc)
# Energy RMSE : 16.885676 meV/atom, MAE: 14.091191 meV/atom
# Forces RMSE: 149.237192 meV/Å, MAE: 105.775388 meV/Å

# %%
# !python /data/home/public/qiuqizhi/LOREM/lorem/results_cumulene.py
# Out:
# /data/home/public/qiuqizhi/LOREM/marathon/marathon/extra/hermes/data_source/flatten_atoms.py:89: FutureWarning: Please use atoms.calc = calc
#   atoms.set_calculator(calc)
# /data/home/public/qiuqizhi/LOREM/marathon/marathon/extra/hermes/data_source/flatten_atoms.py:74: FutureWarning: Please use atoms.calc = calc
#   atoms.set_calculator(calc)

# %%
# %env DATASETS=/data/home/public/qiuqizhi/LOREM/datasets
# %env PYTHONPATH=/data/home/public/qiuqizhi/LOREM
# Out:
# env: DATASETS=/data/home/public/qiuqizhi/LOREM/datasets
# env: PYTHONPATH=/data/home/public/qiuqizhi/LOREM

# %%
# !python /data/home/public/qiuqizhi/LOREM/datasets/prepare.py
# Out:
# /data/home/public/qiuqizhi/LOREM/marathon/marathon/extra/hermes/data_source/flatten_atoms.py:89: FutureWarning: Please use atoms.calc = calc
#   atoms.set_calculator(calc)
# /data/home/public/qiuqizhi/LOREM/marathon/marathon/extra/hermes/data_source/flatten_atoms.py:74: FutureWarning: Please use atoms.calc = calc
#   atoms.set_calculator(calc)
# [marathon]      start processing AuMgO ...
# [marathon]      .. load                                           ✓ (2.137s)
# [marathon]      .. process                                        ✓ (0.000s)
# [marathon]      .. processing                                     ✓ (0.904s)
# [marathon]      per-atom contributions (by species)
# [marathon]       8: -18599.440
# [marathon]       12: -8721.756
# [marathon]       13: -9877.684
# [marathon]       79: -688.868
# [marathon]      .. processing                                     ✓ (0.114s)
# [marathon]      per-atom contributions (by species)
# [marathon]       8: -18599.431
# ...

# %%
# !python /data/home/public/qiuqizhi/LOREM/lorem/run.py
# Out:
# [marathon]      start run ...
# [marathon]      Model Summary                             ⬕
# [marathon]
# [marathon]                                        Lorem Summary
# [marathon]       ┏━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# [marathon]       ┃ path          ┃ module        ┃ inputs        ┃ outputs      ┃ params        ┃
# [marathon]       ┡━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# [marathon]       │               │ Lorem         │ -             │ float32[3]   │               │
# [marathon]       │               │               │ float32[4,3]  │              │               │
# [marathon]       │               │               │ - int32[4]    │              │               │
# [marathon]       │               │               │ - int32[4]    │              │               │
# [marathon]       │               │               │ - int32[3]    │              │               │
# ...
